# %% [markdown]
# # 2026-02-26

# %% [markdown]
# ## 1. Agentisk implementation
#
# **Fokus:** Att använda AI som aktiva “agenter” i verksamheten – inte bara som chattverktyg.
#
# **Vad som menas:**
#
# * Istället för att bygga egna AI-modeller från grunden, använder man befintliga verktyg och kopplar ihop dem.
# * AI-agenter kan:
#
#   * Planera uppgifter
#   * Anropa verktyg (API:er, databaser, interna system)
#   * Utföra steg i en process autonomt
# * Handlar om att integrera AI i faktiska arbetsflöden – inte bara experimentera.
#
# Strategiskt skifte: från “proof of concept” till verklig operativ användning.
#
# ---

# %% [markdown]
# ## 2. Använd verktyg rätt – bygg inte allt själv
#
# **Fokus:** Effektivitet och time-to-market.
#
# **Vad som menas:**
#
# * Företag ska undvika att bygga egna LLM:er eller infrastrukturer om det inte är absolut nödvändigt.
# * Istället:
#
#   * Använd etablerade plattformar
#   * Kombinera färdiga tjänster
#   * Bygg ovanpå befintliga ekosystem
#
# Det är mer en integrationsfråga än en forskningsfråga.
#
# ---

# %% [markdown]
# ## 3. Agenter – determinism vs indeterminism
#
# **Fokus:** Kontroll vs kreativitet i AI-system.
#
# **Determinism:**
#
# * Samma input → samma output
# * Förutsägbart
# * Viktigt i affärskritiska system
#
# **Indeterminism:**
#
# * Samma input kan ge olika svar
# * Mer kreativt och flexibelt
# * Bra för idéarbete, men svårare att kvalitetssäkra
#
# Ledningsperspektivet handlar om:
# Hur mycket variation kan vi acceptera i produktionssystem?
#
# ---

# %% [markdown]
# ## 4. Intern infrastruktur
#
# **Fokus:** AI-mognad i organisationen.
#
# **Vad det inkluderar:**
#
# * Dataåtkomst (API:er, databaser, interna system)
# * Säkerhet och åtkomstkontroll
# * Loggning och spårbarhet
# * GPU/beräkningsresurser (om relevant)
# * CI/CD och versionshantering
#
# Många företag är begränsade mer av sin infrastruktur än av AI-tekniken.
#
# ---

# %% [markdown]
# ## 5. Git branches
#
# **Fokus:** Struktur i AI- och kodutveckling.
#
# **Vad som menas:**
#
# * Tydlig versionshantering
# * Separera experiment från produktion
# * Möjlighet att testa olika AI-flöden parallellt
# * Branch-strategi för prompts och agentlogik
#
# AI-utveckling behöver samma disciplin som traditionell mjukvaruutveckling.
#
# ---

# %% [markdown]
# ## 6. Hugging Face
#
# **Fokus:** Ekosystem för open source-modeller.
#
# **Vad det är:**
# Hugging Face är en plattform för:
#
# * Öppna AI-modeller
# * Modellhosting
# * Fine-tuning
# * Dataset
#
# Relevant för företag som vill ha mer kontroll eller arbeta med open source istället för helt stängda API:er.
#
# ---

# %% [markdown]
# ## 7. Codex
#
# **Fokus:** AI som utvecklarstöd.
#
# OpenAI Codex är en modell som kan:
#
# * Skriva kod
# * Förstå kodbaser
# * Hjälpa till med implementation
#
# 👉 Används för att snabba upp utveckling, särskilt i agentbaserade system.
#
# ---

# %% [markdown]
# ## 8. Projektplanering i fokus – AI som processpartner
#
# **Fokus:** AI före, under och efter projekt.
#
# Istället för att bara använda AI för kod eller text:
#
# * Låt AI ta fram projektplaner
# * Riskanalyser
# * Milstolpar
# * Kommunikationsstruktur
# * Teststrategier
#
# AI blir en “co-pilot” för hela projektprocessen.
#
# ---

# %% [markdown]
# ## 9. Be LLM om plan för prompt inför projekt
#
# **Fokus:** Meta-nivå på AI-användning.
#
# Istället för att direkt skriva prompts:
#
# * Be modellen skapa en promptstrategi
# * Be om struktur för hur AI ska användas i projektet
# * Be om förbättring av egna prompts
#
# Exempel:
#
# > “Skapa en optimal prompt-struktur för att driva ett IT-projekt med hjälp av AI.”
#
# Det handlar om att systematisera AI-användningen.
#
# ---

# %% [markdown]
# # Övergripande tema från företagen
#
# Det som tydligt framgår är:
#
# * Fokus på implementation, inte experiment
# * Fokus på struktur och styrning
# * Fokus på integration i befintlig verksamhet
# * AI som operativ resurs, inte innovationsleksak
